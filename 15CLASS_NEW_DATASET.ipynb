# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ReduceLROnPlateau
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l2
from PIL import Image
import numpy as np
import os
import re
import random
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix

# **Updated dataset path**
dataset_path = "/content/drive/MyDrive/BTP/text_image_dataset_new"  # New dataset folder
csv_path = "new_labels.csv"

# Load CSV file
data = pd.read_csv(csv_path)

# Font styles and sizes
fonts = ["Arial", "Times New Roman", "Courier New", "Verdana", "Georgia"]
sizes = [16, 24, 32]

# Create a unique class for each (font, size) combination
font_size_combinations = [(f, s) for f in range(len(fonts)) for s in sizes]
class_mapping = {comb: idx for idx, comb in enumerate(font_size_combinations)}

def extract_label_from_filename(filename):
    match = re.match(r'font_(\d+)_sample_\d+_size_(\d+)', filename)
    if match:
        font_class = int(match.group(1))
        size = int(match.group(2))
        return font_class, size
    return None, None

# **Reload dataset with new folder**
images = []
labels = []

for index, row in data.iterrows():
    image_path = os.path.join(dataset_path, row['filename'])

    if os.path.exists(image_path):
        img = Image.open(image_path).convert("L")
        img = img.resize((32, 32))
        img = np.array(img) / 255.0

        font_class, size = extract_label_from_filename(row['filename'])
        if font_class is not None and size in sizes:
            combined_label = class_mapping[(font_class, size)]
            images.append(img)
            labels.append(combined_label)

# Convert to numpy arrays
images = np.array(images).reshape(-1, 32, 32, 1)
labels = to_categorical(labels, num_classes=len(font_size_combinations))

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(
    images, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Total images: {len(images)}")
print(f"Train set: {len(x_train)}, Test set: {len(x_test)}")

# **Set random seed for reproducibility**
seed = 42
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)

# **Define LeNet model**
def build_lenet():
    inputs = layers.Input(shape=(32, 32, 1))

    x = layers.Conv2D(6, (5, 5), activation='relu', padding='valid',
                     kernel_initializer=tf.keras.initializers.HeNormal(seed=seed),
                      kernel_regularizer=l2(0.01)
                    )(inputs)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Conv2D(16, (5, 5), activation='relu', padding='valid',
                     kernel_initializer=tf.keras.initializers.HeNormal(seed=seed),
                      kernel_regularizer=l2(0.01)
                    )(x)
    x = layers.MaxPooling2D((2, 2))(x)

    x = layers.Flatten()(x)
    x = layers.Dense(120, activation='relu',
                     kernel_initializer=tf.keras.initializers.HeNormal(seed=seed),
                      kernel_regularizer=l2(0.01)
                    )(x)

    x = layers.Dense(84, activation='relu',
                     kernel_initializer=tf.keras.initializers.HeNormal(seed=seed),
                      kernel_regularizer=l2(0.01)
                    )(x)

    output = layers.Dense(len(font_size_combinations), activation='softmax', name='output',
                          kernel_initializer=tf.keras.initializers.GlorotUniform(seed=seed))(x)

    model = tf.keras.Model(inputs=inputs, outputs=output)
    return model

# **Compile the model**
model = build_lenet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# **Callbacks**
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=3,
    min_lr=1e-5
)

# **Train the model with new dataset**
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping, lr_scheduler]
)

# **Plot Loss**
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# **Evaluate Model**
test_results = model.evaluate(x_test, y_test)
print(f"Test Results: {test_results}")

# **Predictions**
predictions = model.predict(x_test)
predicted_indices = np.argmax(predictions, axis=1)
actual_indices = np.argmax(y_test, axis=1)

# **Map back to font and size**
predicted_classes = [font_size_combinations[idx] for idx in predicted_indices]
actual_classes = [font_size_combinations[idx] for idx in actual_indices]

predicted_fonts = [fonts[f] for f, s in predicted_classes]
actual_fonts = [fonts[f] for f, s in actual_classes]
predicted_sizes = [s for f, s in predicted_classes]
actual_sizes = [s for f, s in actual_classes]

# **Display results**
df_results = pd.DataFrame({
    "Actual Font": actual_fonts[:20],
    "Predicted Font": predicted_fonts[:20],
    "Actual Size": actual_sizes[:20],
    "Predicted Size": predicted_sizes[:20]
})

print(df_results)

# **Confusion Matrix**
cm = confusion_matrix(actual_indices, predicted_indices)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=range(len(font_size_combinations)),
            yticklabels=range(len(font_size_combinations)))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Total images: 1005
# Train set: 804, Test set: 201
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.0769 - loss: 7.0407 - val_accuracy: 0.1294 - val_loss: 5.9565 - learning_rate: 0.0010
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.1306 - loss: 5.7172 - val_accuracy: 0.2537 - val_loss: 5.0402 - learning_rate: 0.0010
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.2154 - loss: 4.8734 - val_accuracy: 0.2736 - val_loss: 4.3714 - learning_rate: 0.0010
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.2180 - loss: 4.2513 - val_accuracy: 0.2687 - val_loss: 3.8315 - learning_rate: 0.0010
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2637 - loss: 3.7244 - val_accuracy: 0.3881 - val_loss: 3.3028 - learning_rate: 0.0010
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3913 - loss: 3.2177 - val_accuracy: 0.5970 - val_loss: 2.6936 - learning_rate: 0.0010
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5802 - loss: 2.6917 - val_accuracy: 0.6667 - val_loss: 2.2462 - learning_rate: 0.0010
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7146 - loss: 2.2644 - val_accuracy: 0.8010 - val_loss: 1.9428 - learning_rate: 0.0010
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7925 - loss: 1.9329 - val_accuracy: 0.8557 - val_loss: 1.7326 - learning_rate: 0.0010
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8840 - loss: 1.7135 - val_accuracy: 0.8806 - val_loss: 1.6070 - learning_rate: 0.0010
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9023 - loss: 1.5681 - val_accuracy: 0.9453 - val_loss: 1.4419 - learning_rate: 0.0010
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9258 - loss: 1.4411 - val_accuracy: 0.9652 - val_loss: 1.2907 - learning_rate: 0.0010
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9653 - loss: 1.3177 - val_accuracy: 0.9851 - val_loss: 1.2073 - learning_rate: 0.0010
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9794 - loss: 1.2251 - val_accuracy: 0.9851 - val_loss: 1.1516 - learning_rate: 0.0010
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9812 - loss: 1.1660 - val_accuracy: 0.9900 - val_loss: 1.1017 - learning_rate: 0.0010
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9845 - loss: 1.1157 - val_accuracy: 0.9950 - val_loss: 1.0589 - learning_rate: 0.0010
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9857 - loss: 1.0710 - val_accuracy: 0.9950 - val_loss: 1.0207 - learning_rate: 0.0010
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9901 - loss: 1.0322 - val_accuracy: 0.9950 - val_loss: 0.9856 - learning_rate: 0.0010
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9920 - loss: 0.9960 - val_accuracy: 0.9950 - val_loss: 0.9531 - learning_rate: 0.0010
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9931 - loss: 0.9636 - val_accuracy: 0.9950 - val_loss: 0.9242 - learning_rate: 0.0010
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9931 - loss: 0.9338 - val_accuracy: 1.0000 - val_loss: 0.8944 - learning_rate: 0.0010
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9955 - loss: 0.9043 - val_accuracy: 1.0000 - val_loss: 0.8706 - learning_rate: 0.0010
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9955 - loss: 0.8798 - val_accuracy: 1.0000 - val_loss: 0.8467 - learning_rate: 0.0010
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9955 - loss: 0.8561 - val_accuracy: 1.0000 - val_loss: 0.8251 - learning_rate: 0.0010
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.8344 - val_accuracy: 1.0000 - val_loss: 0.8057 - learning_rate: 0.0010
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 0.8146 - val_accuracy: 1.0000 - val_loss: 0.7866 - learning_rate: 0.0010
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.7959 - val_accuracy: 1.0000 - val_loss: 0.7698 - learning_rate: 0.0010
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.7790 - val_accuracy: 1.0000 - val_loss: 0.7550 - learning_rate: 0.0010
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.7638 - val_accuracy: 1.0000 - val_loss: 0.7439 - learning_rate: 0.0010
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.7509 - val_accuracy: 1.0000 - val_loss: 0.7376 - learning_rate: 0.0010
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.7381 - val_accuracy: 1.0000 - val_loss: 0.7217 - learning_rate: 0.0010
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.7189 - val_accuracy: 1.0000 - val_loss: 0.6999 - learning_rate: 0.0010
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.7008 - val_accuracy: 1.0000 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.6881 - val_accuracy: 1.0000 - val_loss: 0.6742 - learning_rate: 0.0010
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.6775 - val_accuracy: 1.0000 - val_loss: 0.6630 - learning_rate: 0.0010
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.6673 - val_accuracy: 1.0000 - val_loss: 0.6524 - learning_rate: 0.0010
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.6571 - val_accuracy: 1.0000 - val_loss: 0.6426 - learning_rate: 0.0010
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.6468 - val_accuracy: 1.0000 - val_loss: 0.6328 - learning_rate: 0.0010
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.6367 - val_accuracy: 1.0000 - val_loss: 0.6237 - learning_rate: 0.0010
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.6267 - val_accuracy: 1.0000 - val_loss: 0.6149 - learning_rate: 0.0010
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.6168 - val_accuracy: 1.0000 - val_loss: 0.6049 - learning_rate: 0.0010
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.6074 - val_accuracy: 1.0000 - val_loss: 0.5956 - learning_rate: 0.0010
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.5985 - val_accuracy: 1.0000 - val_loss: 0.5874 - learning_rate: 0.0010
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.5904 - val_accuracy: 1.0000 - val_loss: 0.5788 - learning_rate: 0.0010
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.5825 - val_accuracy: 1.0000 - val_loss: 0.5714 - learning_rate: 0.0010
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.5748 - val_accuracy: 1.0000 - val_loss: 0.5635 - learning_rate: 0.0010
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.5674 - val_accuracy: 1.0000 - val_loss: 0.5568 - learning_rate: 0.0010
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5604 - val_accuracy: 1.0000 - val_loss: 0.5498 - learning_rate: 0.0010
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.5534 - val_accuracy: 1.0000 - val_loss: 0.5419 - learning_rate: 0.0010
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.5466 - val_accuracy: 1.0000 - val_loss: 0.5344 - learning_rate: 0.0010
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5403 - val_accuracy: 1.0000 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.5350 - val_accuracy: 1.0000 - val_loss: 0.5223 - learning_rate: 0.0010
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.5306 - val_accuracy: 1.0000 - val_loss: 0.5209 - learning_rate: 0.0010
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5273 - val_accuracy: 1.0000 - val_loss: 0.5247 - learning_rate: 0.0010
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5235 - val_accuracy: 1.0000 - val_loss: 0.5197 - learning_rate: 0.0010
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5143 - val_accuracy: 1.0000 - val_loss: 0.5016 - learning_rate: 0.0010
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.5031 - val_accuracy: 1.0000 - val_loss: 0.4955 - learning_rate: 0.0010
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4987 - val_accuracy: 1.0000 - val_loss: 0.4934 - learning_rate: 0.0010
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4966 - val_accuracy: 1.0000 - val_loss: 0.4924 - learning_rate: 0.0010
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4937 - val_accuracy: 1.0000 - val_loss: 0.4901 - learning_rate: 0.0010
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4902 - val_accuracy: 1.0000 - val_loss: 0.4857 - learning_rate: 0.0010
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.4850 - val_accuracy: 1.0000 - val_loss: 0.4765 - learning_rate: 0.0010
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4774 - val_accuracy: 1.0000 - val_loss: 0.4686 - learning_rate: 0.0010
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.4715 - val_accuracy: 1.0000 - val_loss: 0.4646 - learning_rate: 0.0010
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.4684 - val_accuracy: 1.0000 - val_loss: 0.4627 - learning_rate: 0.0010
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.4665 - val_accuracy: 1.0000 - val_loss: 0.4618 - learning_rate: 0.0010
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 0.4637 - val_accuracy: 1.0000 - val_loss: 0.4607 - learning_rate: 0.0010
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.4614 - val_accuracy: 1.0000 - val_loss: 0.4582 - learning_rate: 0.0010
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4571 - val_accuracy: 1.0000 - val_loss: 0.4482 - learning_rate: 0.0010
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.4495 - val_accuracy: 1.0000 - val_loss: 0.4406 - learning_rate: 0.0010
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4443 - val_accuracy: 1.0000 - val_loss: 0.4368 - learning_rate: 0.0010
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4422 - val_accuracy: 1.0000 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4402 - val_accuracy: 1.0000 - val_loss: 0.4348 - learning_rate: 0.0010
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 0.4383 - val_accuracy: 1.0000 - val_loss: 0.4354 - learning_rate: 0.0010
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4373 - val_accuracy: 1.0000 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4345 - val_accuracy: 1.0000 - val_loss: 0.4278 - learning_rate: 0.0010
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4273 - val_accuracy: 1.0000 - val_loss: 0.4181 - learning_rate: 0.0010
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.4223 - val_accuracy: 1.0000 - val_loss: 0.4144 - learning_rate: 0.0010
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.4202 - val_accuracy: 1.0000 - val_loss: 0.4125 - learning_rate: 0.0010
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.4178 - val_accuracy: 1.0000 - val_loss: 0.4116 - learning_rate: 0.0010
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.4165 - val_accuracy: 1.0000 - val_loss: 0.4118 - learning_rate: 0.0010
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.4155 - val_accuracy: 1.0000 - val_loss: 0.4130 - learning_rate: 0.0010
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.4137 - val_accuracy: 1.0000 - val_loss: 0.4109 - learning_rate: 0.0010
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.4098 - val_accuracy: 1.0000 - val_loss: 0.4002 - learning_rate: 0.0010
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 0.4034 - val_accuracy: 1.0000 - val_loss: 0.3965 - learning_rate: 0.0010
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.4032 - val_accuracy: 1.0000 - val_loss: 0.3946 - learning_rate: 0.0010
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.4001 - val_accuracy: 1.0000 - val_loss: 0.3912 - learning_rate: 0.0010
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.3964 - val_accuracy: 1.0000 - val_loss: 0.3897 - learning_rate: 0.0010
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3953 - val_accuracy: 1.0000 - val_loss: 0.3899 - learning_rate: 0.0010
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3943 - val_accuracy: 1.0000 - val_loss: 0.3925 - learning_rate: 0.0010
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 0.3947 - val_accuracy: 1.0000 - val_loss: 0.3955 - learning_rate: 0.0010
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3889 - val_accuracy: 1.0000 - val_loss: 0.3800 - learning_rate: 5.0000e-04
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3805 - val_accuracy: 1.0000 - val_loss: 0.3787 - learning_rate: 5.0000e-04
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.3786 - val_accuracy: 1.0000 - val_loss: 0.3772 - learning_rate: 5.0000e-04
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3773 - val_accuracy: 1.0000 - val_loss: 0.3757 - learning_rate: 5.0000e-04
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3760 - val_accuracy: 1.0000 - val_loss: 0.3746 - learning_rate: 5.0000e-04
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3749 - val_accuracy: 1.0000 - val_loss: 0.3736 - learning_rate: 5.0000e-04
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3740 - val_accuracy: 1.0000 - val_loss: 0.3728 - learning_rate: 5.0000e-04
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3729 - val_accuracy: 1.0000 - val_loss: 0.3718 - learning_rate: 5.0000e-04
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.3720 - val_accuracy: 1.0000 - val_loss: 0.3709 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.3754
# Test Results: [0.3709285855293274, 1.0]
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#         Actual Font   Predicted Font  Actual Size  Predicted Size
# 0   Times New Roman  Times New Roman           32              32
# 1           Verdana          Verdana           16              16
# 2           Georgia          Georgia           32              32
# 3           Verdana          Verdana           32              32
# 4   Times New Roman  Times New Roman           24              24
# 5   Times New Roman  Times New Roman           32              32
# 6       Courier New      Courier New           24              24
# 7             Arial            Arial           32              32
# 8       Courier New      Courier New           32              32
# 9           Verdana          Verdana           24              24
# 10      Courier New      Courier New           16              16
# 11  Times New Roman  Times New Roman           16              16
# 12  Times New Roman  Times New Roman           24              24
# 13          Verdana          Verdana           24              24
# 14      Courier New      Courier New           32              32
# 15          Verdana          Verdana           16              16
# 16  Times New Roman  Times New Roman           16              16
# 17          Georgia          Georgia           24              24
# 18            Arial            Arial           16              16
# 19          Georgia          Georgia           16              16
